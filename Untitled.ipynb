# %%
liste = ["path","probably","reside","current","title","access","straight","content","provide","mad"]



dongu = 1
while dongu < 5:
    b = random.choice(liste)
    if b == "path":
        print(b,"=")
        cevap = input("cevap= ")
        if cevap == "yol":
            print("doğru")
        else:
            print("yanlış")  
    elif b == "probably":
        print(b)
        cevap = input("cevap= ")
        if cevap == "muhtemelen" or cevap == "büyük olasılıkla":
            print("doğru")
        else:
            print("yanlış")
    elif b == "reside":
        print(b)
        cevap = input("cevap= ")
        if cevap == "ikamet":
            print("doğru")
        else:
            print("yanlış")
    elif b == "current":
        print(b,"=")
        cevap = input("cevap= ")
        if cevap == "mevcut":
            print("doğru")
        else:
            print("yanlış")
    elif b == "title":
        print(b,"=")
        cevap = input("cevap= ")
        if cevap == "başlık":
            print("doğru")
        else:
            print("yanlış")
    elif b == "access":
        print(b,"=")
        cevap = input("cevap= ")
        if cevap == "erişim":
            print("doğru")
        else:
            print("yanlış,","doğrusu= erişim")
    elif b == "straight":
        print(b,"=")
        cevap = input("cevap= ")
        if cevap == "düz":
            print("doğru")
        else:
            print("yanlış,","doğrusu=düz")
    elif b == "content":
        print(b,"=")
        cevap = input("cevap= ")
        if cevap == "içerik":
            print("doğru")
        else:
            print("yanlış,","doğrusu=içerik")
    elif b == "provide":
        print(b,"=")
        cevap = input("cevap= ")
        if cevap == "sağlamak":
            print("doğru")
        else:
            print("yanlış,","doğrusu= sağlamak")
    elif b == "mad":
        print(b,"=")
        cevap = input("cevap= ")
        if cevap == "deli":
            print("doğru")
        else:
            print("yanlış,","doğrusu= deli")
